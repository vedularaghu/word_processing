# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
df1 = pd.read_csv("./data/a1.filtered.csv")
df2 = pd.read_csv("./data/a2.filtered.csv")
df3 = pd.read_csv("./data/a3.filtered.csv")
df4 = pd.read_csv("./data/a4.filtered.csv")

# %%
df1[' Value'].plot()
df2[' Value'].plot()
df3[' Value'].plot()
df4[' Value'].plot()

# %%
df1['Label'] = [1 for i in range(len(df1))]
df2['Label'] = [2 for i in range(len(df2))]
df3['Label'] = [3 for i in range(len(df3))]
df4['Label'] = [4 for i in range(len(df4))]

# %%
df = pd.DataFrame()

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.to_csv('combined_words.csv', index=False)

# %%
df.columns
# Out:
# Index(['%Time', ' Value', 'Label'], dtype='object')

# %%
df1.plot(title="Word ON", )
plt.savefig("ON.png")
df2.plot(title="Word OFF")
plt.savefig("OFF.png")
df3.plot(title="Word RIGHT")
plt.savefig("RIGHT.png")
df4.plot(title="Word LEFT")
plt.savefig("LEFT.png")

# %%
df.drop(['%Time'], axis=1, inplace=True)

# %%
from sklearn.model_selection import train_test_split

# %%
X = df[' Value']
y = df['Label']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
from sklearn.model_selection import cross_validate

# %%
knn = KNeighborsClassifier(n_neighbors=3)

# %%
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=3, p=2,
#            weights='uniform')

# %%
X_test = X_test.reshape(-1,1)

# %%
knn.score(X_test,y_test)
# Out:
# 0.29622395833333331

# %%
X_train = X_train.reshape(-1,1)
# Out:
# /home/vedula/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   """Entry point for launching an IPython kernel.

# %%
clf = svm.LinearSVC()

# %%
clf.fit(X_train, y_train)
# Out:
# LinearSVC(C=1.0, class_weight=None, dual=True, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#      verbose=0)

# %%
clf.score(X_test,y_test)
# Out:
# 0.2294921875
